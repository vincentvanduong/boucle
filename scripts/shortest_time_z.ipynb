# %% [markdown]
# This notebook plots a qubit and the control

# %%
# %config InlineBackend.figure_format = "retina"
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import rcParams

rcParams["figure.figsize"] = [6, 2]
rcParams["figure.dpi"] = 350
rcParams["font.size"] = 14

import numpy as np
import jax.numpy as jnp
import jax

# %%
duration = []
cost = []
entropy = []

with open('/Users/vincentduong/dev/boucle/data/shortest_time_log4.txt', 'r') as f:
    for line in f.readlines():
        l = line.strip().split('=')
        
        if l[0].strip() == 'Duration':
            duration.append(float(l[1].strip()))

        elif l[0].strip() == 'Cost':
            cost.append(float(l[1].strip()))

        elif l[0].strip() == 'Entropy':
            entropy.append(float(l[1].strip()))



duration4, cost4, entropy4 = duration, cost, entropy

# %%
duration = []
cost = []
entropy = []

with open('/Users/vincentduong/dev/boucle/data/shortest_time_log7.txt', 'r') as f:
    for line in f.readlines():
        l = line.strip().split('=')
        
        if l[0].strip() == 'Duration':
            duration.append(float(l[1].strip()))

        elif l[0].strip() == 'Cost':
            cost.append(float(l[1].strip()))

        elif l[0].strip() == 'Entropy':
            entropy.append(float(l[1].strip()))

duration3, cost3, entropy3 = duration, cost, entropy

# %%
duration = []
cost = []
entropy = []

with open('/Users/vincentduong/dev/boucle/data/shortest_time_log8.txt', 'r') as f:
    for line in f.readlines():
        l = line.strip().split('=')
        
        if l[0].strip() == 'Duration':
            duration.append(float(l[1].strip()))

        elif l[0].strip() == 'Cost':
            cost.append(float(l[1].strip()))

        elif l[0].strip() == 'Entropy':
            entropy.append(float(l[1].strip()))


duration2, cost2, entropy2 = duration, cost, entropy

# %%
duration = []
cost = []
entropy = []

with open('/Users/vincentduong/dev/boucle/data/shortest_time_log9.txt', 'r') as f:
    for line in f.readlines():
        l = line.strip().split('=')
        
        if l[0].strip() == 'Duration':
            duration.append(float(l[1].strip()))

        elif l[0].strip() == 'Cost':
            cost.append(float(l[1].strip()))

        elif l[0].strip() == 'Entropy':
            entropy.append(float(l[1].strip()))

duration1, cost1, entropy1 = duration, cost, entropy

# %%
fig, ax = plt.subplots(figsize=(6, 3))

# -------------------BEGIN-CHANGES------------------------
# Define font sizes
SIZE_DEFAULT = 14
SIZE_LARGE = 16
plt.rc('text', usetex=True)
plt.rc("font", weight="normal")  # controls default font
plt.rc("font", size=SIZE_DEFAULT)  # controls default text sizes
plt.rc("axes", titlesize=SIZE_LARGE)  # fontsize of the axes title
plt.rc("axes", labelsize=SIZE_LARGE)  # fontsize of the x and y labels
plt.rc("xtick", labelsize=SIZE_DEFAULT)  # fontsize of the tick labels
plt.rc("ytick", labelsize=SIZE_DEFAULT)  # fontsize of the tick labels
# --------------------END CHANGES------------------------


ax.plot(duration4, cost4, color='r', label='$L=4$', linewidth=2)
#ax.plot(duration3, cost3, color='g', label='$L=3$', linewidth=2)
ax.plot(duration2, cost2, color='b', label='$L=2$', linewidth=2)
ax.plot(duration1, cost1, color='m', label='$L=1$', linewidth=2)
plt.xlabel('Time $T$')
plt.ylabel('Cost')
plt.xlim(0,2)
#plt.ylim(-1,-0.8)
#plt.axhline(y = -7.174305188161573, color = 'b', linestyle = '--', label='DMRG')
#plt.ylim(-8,2)
ax.legend()

# Hide the all but the bottom spines (axis lines)
##ax.spines["right"].set_visible(False)
#ax.spines["left"].set_visible(True)
#ax.spines["top"].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position("left")
ax.xaxis.set_ticks_position("bottom")
ax.grid()
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 3))

# -------------------BEGIN-CHANGES------------------------
# Define font sizes
SIZE_DEFAULT = 14
SIZE_LARGE = 16
plt.rc('text', usetex=True)
plt.rc("font", weight="normal")  # controls default font
plt.rc("font", size=SIZE_DEFAULT)  # controls default text sizes
plt.rc("axes", titlesize=SIZE_LARGE)  # fontsize of the axes title
plt.rc("axes", labelsize=SIZE_LARGE)  # fontsize of the x and y labels
plt.rc("xtick", labelsize=SIZE_DEFAULT)  # fontsize of the tick labels
plt.rc("ytick", labelsize=SIZE_DEFAULT)  # fontsize of the tick labels
# --------------------END CHANGES------------------------


ax.plot(duration4, cost4, color='r', label='$L=4$', linewidth=2)
#ax.plot(duration3, cost3, color='g', label='$L=3$', linewidth=2)
ax.plot(duration2, cost2, color='b', label='$L=2$', linewidth=2)
ax.plot(duration1, cost1, color='m', label='$L=1$', linewidth=2)
plt.xlabel('Time $T$')
plt.ylabel('Cost')
plt.xlim(0.25,2)
plt.ylim(-1.01,-0.85)
#plt.axhline(y = -7.174305188161573, color = 'b', linestyle = '--', label='DMRG')
#plt.ylim(-8,2)
ax.legend()

# Hide the all but the bottom spines (axis lines)
##ax.spines["right"].set_visible(False)
#ax.spines["left"].set_visible(True)
#ax.spines["top"].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position("left")
ax.xaxis.set_ticks_position("bottom")
ax.grid()
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 3))

# -------------------BEGIN-CHANGES------------------------
# Define font sizes
SIZE_DEFAULT = 14
SIZE_LARGE = 16
plt.rc('text', usetex=True)
plt.rc("font", weight="normal")  # controls default font
plt.rc("font", size=SIZE_DEFAULT)  # controls default text sizes
plt.rc("axes", titlesize=SIZE_LARGE)  # fontsize of the axes title
plt.rc("axes", labelsize=SIZE_LARGE)  # fontsize of the x and y labels
plt.rc("xtick", labelsize=SIZE_DEFAULT)  # fontsize of the tick labels
plt.rc("ytick", labelsize=SIZE_DEFAULT)  # fontsize of the tick labels
# --------------------END CHANGES------------------------


ax.plot(duration4, 1*np.array(entropy4), color='r', label='$L=4$', linewidth=2)
#ax.plot(duration3, entropy3, color='g', label='$L=3$', linewidth=2)
ax.plot(duration2, 1*np.array(entropy2), color='b', label='$L=2$', linewidth=2)
ax.plot(duration1, entropy1, color='m', label='$L=1$', linewidth=2)
plt.xlabel('Time $T$')
plt.ylabel('Entropy')
plt.xlim(0.25,2)
ax.legend()

# Hide the all but the bottom spines (axis lines)
#ax.spines["right"].set_visible(False)
#ax.spines["left"].set_visible(True)
#ax.spines["top"].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position("left")
ax.xaxis.set_ticks_position("bottom")
ax.grid()
plt.tight_layout()
plt.show()
