# %% [markdown]
# This notebook plots a qubit and the control

# %%
# %config InlineBackend.figure_format = "retina"
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import rcParams

rcParams["figure.figsize"] = [6, 2]
rcParams["figure.dpi"] = 350
rcParams["font.size"] = 14

import pandas as pd
import numpy as np
import jax.numpy as jnp
import jax
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 10
#       7 rcParams["figure.dpi"] = 350
#       8 rcParams["font.size"] = 14
# ---> 10 import pandas as pd
#      11 import numpy as np
#      12 import jax.numpy as jnp
#
# ModuleNotFoundError: No module named 'pandas'

# %%
data = {
  "Control": np.array([-4.0, -4.0, 4.0, -4.0, 4.0, 4.0, 4.0, 4.0, 4.0, -4.0, 4.0, -4.0, -4.0, 4.0, -4.0, 4.0, -4.0, -4.0, 4.0, 4.0, -4.0, 4.0, -4.0, -4.0, 4.0, -4.0, 4.0]),
  "Cost": np.array([2.3955303262721883, 2.8833039572097965, 1.1548962981993633, 1.8037726918040344, -0.28440965914630356, -2.0046672412743476, -2.7850296675570867, -2.4234679212826813, -1.1707568709569092, -1.5114346406801913, -0.7757607085310972, -0.9209785206984885, -0.6752693173516735, -1.6942487028878248, -1.2682296776208697, -2.7405053718970507, -2.1938856817730947, -1.465289272087093, -3.667638360649914, -5.321594543802062, -4.808121600958707, -6.143361398638439, -5.772366316944635, -5.236451159435806, -6.533980469145, -6.209312879513911, -6.80378274978401]),
  "Fidelity": np.array([0.44027304632846564, 0.395405033156965, 0.5394405917834383, 0.48918175841505435, 0.6387682200272835, 0.7295891819796718, 0.7428419319024385, 0.6738447419655986, 0.5334976584455533, 0.575732308428936, 0.49127326058748305, 0.5032649733973187, 0.4854034766478812, 0.584451411452943, 0.5387540163121013, 0.6854892684648424, 0.6344055669165976, 0.564470420179048, 0.7579227584161587, 0.8790003130149662, 0.8429325178713655, 0.9346770951522048, 0.9096229433357793, 0.8718382823613551, 0.9635256459020352, 0.9401085954688196, 0.9869391612274007]),
  "Sx": np.array([-2.2497909256258004, -2.0091214187429656, -1.721924903817214, -1.401605944468158, -1.05468531794666, -0.7690475448744765, -0.6393581100135124, -0.6991070751850235, -0.9069080983890176, -1.0750567126536752, -1.1971636168020783, -1.2688693965585256, -1.1475601113133649, -0.9783512471801419, -0.7680143356349097, -0.5237008074504614, -0.25377419856317074, 0.10691694063980241, 0.4726400739275403, 0.7469773870781932, 1.0007476442110887, 1.2221961416487845, 1.405605268692813, 1.671024005693158, 1.8863383385235144, 2.047449996290333, 2.1461390535577065]),
  "Sy": np.array([1.068637707841052, 1.9086101546450054, 1.6016094596819905, 2.3416297247521745, 1.9244104821607373, 1.1823464926593736, 0.24715743864994774, -0.7038337398212136, -1.4980160300860283, -0.31824252140352605, -1.0505303946008664, 0.17306329397381023, 1.359751829801802, 0.6370349669826425, 1.7630877583728848, 0.9638263724364261, 1.9999940899372464, 2.670333120844765, 2.0298506041333133, 0.9868027269524683, 1.7882110288198094, 0.6506223939533476, 1.3697179626899472, 1.8565509856567808, 0.8403165345734755, 1.2514460205707676, 0.17867070241359448]),
  "Sz": np.array([1.6331200440390066, 1.0262296837384224, 1.7379002247235116, 0.9345080318213522, 1.7998743365320546, 2.4302069183643904, 2.719564357757893, 2.625390476293874, 2.1770674101655962, 2.546260822108629, 2.267890429537396, 2.446411921864835, 2.1342837507668744, 2.539924054362736, 2.051779741217306, 2.6065549248450006, 2.0041751139258683, 1.0554090741418936, 2.0114907131667, 2.625993467694454, 2.0625492647383292, 2.559560093530218, 2.1495018455653616, 1.4951030314140854, 2.0447370684366195, 1.6209084075653633, 1.9125539799919316])
}

time = np.linspace(0.05, 2.75,27)

# %%
data["Fidelity"][-1]
# Out:
# 0.9869391612274007

# %%
fig, ax = plt.subplots(figsize=(6, 3))

# -------------------BEGIN-CHANGES------------------------
# Define font sizes
SIZE_DEFAULT = 14
SIZE_LARGE = 16
plt.rc('text', usetex=True)
plt.rc("font", weight="normal")  # controls default font
plt.rc("font", size=SIZE_DEFAULT)  # controls default text sizes
plt.rc("axes", titlesize=SIZE_LARGE)  # fontsize of the axes title
plt.rc("axes", labelsize=SIZE_LARGE)  # fontsize of the x and y labels
plt.rc("xtick", labelsize=SIZE_DEFAULT)  # fontsize of the tick labels
plt.rc("ytick", labelsize=SIZE_DEFAULT)  # fontsize of the tick labels
# --------------------END CHANGES------------------------


ax.plot(time, data["Cost"], color='r', label="Protocol", linewidth=2)
plt.xlabel('Time $t$')
plt.ylabel('Cost')

ax.plot(2.75,-6.8,'ro') 

#plt.xlim(0,1)
#plt.ylim(-1,-0.8)
plt.text(2.55, -5.8, "$-6.80$")
plt.text(-0.4, -7.4, "$-7.17$")
plt.axhline(y = -7.174305188161573, color = 'b', linestyle = '--', label='DMRG')
#plt.ylim(-8,2)
ax.legend()

# Hide the all but the bottom spines (axis lines)
##ax.spines["right"].set_visible(False)
#ax.spines["left"].set_visible(True)
#ax.spines["top"].set_visible(False)

# Only show ticks on the left and bottom spines

ax.yaxis.set_ticks_position("left")
ax.xaxis.set_ticks_position("bottom")
ax.grid()
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 3))

# -------------------BEGIN-CHANGES------------------------
# Define font sizes
SIZE_DEFAULT = 14
SIZE_LARGE = 16
plt.rc('text', usetex=True)
plt.rc("font", weight="normal")  # controls default font
plt.rc("font", size=SIZE_DEFAULT)  # controls default text sizes
plt.rc("axes", titlesize=SIZE_LARGE)  # fontsize of the axes title
plt.rc("axes", labelsize=SIZE_LARGE)  # fontsize of the x and y labels
plt.rc("xtick", labelsize=SIZE_DEFAULT)  # fontsize of the tick labels
plt.rc("ytick", labelsize=SIZE_DEFAULT)  # fontsize of the tick labels
# --------------------END CHANGES------------------------


ax.plot(time, data["Fidelity"], color='r', label="Protocol", linewidth=2)
ax.plot(2.75,0.986,'ro')
plt.xlabel('Time $t$')
plt.ylabel('Fidelity')
#plt.xlim(0,1)
#plt.ylim(-1,-0.8)
plt.axhline(y = 1, color = 'b', linestyle = '--', label="DMRG")
#plt.ylim(-8,2)
ax.legend()

plt.text(2.6, 0.8755, "$0.986$")


# Hide the all but the bottom spines (axis lines)
##ax.spines["right"].set_visible(False)
#ax.spines["left"].set_visible(True)
#ax.spines["top"].set_visible(False)

# Only show ticks on the left and bottom spines

ax.yaxis.set_ticks_position("left")
ax.xaxis.set_ticks_position("bottom")
ax.grid()
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6,3))

# -------------------BEGIN-CHANGES------------------------
# Define font sizes
SIZE_DEFAULT = 14
SIZE_LARGE = 16
plt.rc('text', usetex=True)
plt.rc("font", weight="normal")  # controls default font
plt.rc("font", size=SIZE_DEFAULT)  # controls default text sizes
plt.rc("axes", titlesize=SIZE_LARGE)  # fontsize of the axes title
plt.rc("axes", labelsize=SIZE_LARGE)  # fontsize of the x and y labels
plt.rc("xtick", labelsize=SIZE_DEFAULT)  # fontsize of the tick labels
plt.rc("ytick", labelsize=SIZE_DEFAULT)  # fontsize of the tick labels
# --------------------END CHANGES------------------------


ax.step(time-0.05, data["Control"], color='r', label="$h(t)$", linewidth=2)
plt.xlabel('Time $t$')
plt.ylabel('Control')
#plt.xlim(0,1)
#plt.ylim(-1,-0.8)
#plt.axhline(y = -7.174305188161573, color = 'b', linestyle = '--', label='DMRG')
#plt.ylim(-8,2)
#ax.legend()

# Hide the all but the bottom spines (axis lines)
##ax.spines["right"].set_visible(False)
#ax.spines["left"].set_visible(True)
#ax.spines["top"].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position("left")
ax.xaxis.set_ticks_position("bottom")
ax.grid()
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 3))

# -------------------BEGIN-CHANGES------------------------
# Define font sizes
SIZE_DEFAULT = 14
SIZE_LARGE = 16
plt.rc('text', usetex=True)
plt.rc("font", weight="normal")  # controls default font
plt.rc("font", size=SIZE_DEFAULT)  # controls default text sizes
plt.rc("axes", titlesize=SIZE_LARGE)  # fontsize of the axes title
plt.rc("axes", labelsize=SIZE_LARGE)  # fontsize of the x and y labels
plt.rc("xtick", labelsize=SIZE_DEFAULT)  # fontsize of the tick labels
plt.rc("ytick", labelsize=SIZE_DEFAULT)  # fontsize of the tick labels
# --------------------END CHANGES------------------------


ax.plot(time, data["Sx"], color='r', label=r"$\langle S_x \rangle $", linewidth=2)
ax.plot(time, data["Sy"], color='g', label=r"$\langle S_y \rangle $", linewidth=2)
ax.plot(time, data["Sz"], color='b', label=r"$\langle S_z \rangle $", linewidth=2)
plt.xlabel('Time $t$')
plt.ylabel('Expectation values')
#plt.xlim(0,1)
#plt.ylim(-1,-0.8)
#plt.axhline(y = -7.174305188161573, color = 'b', linestyle = '--', label='DMRG')
#plt.ylim(-8,2)
ax.legend()

# Hide the all but the bottom spines (axis lines)
##ax.spines["right"].set_visible(False)
#ax.spines["left"].set_visible(True)
#ax.spines["top"].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position("left")
ax.xaxis.set_ticks_position("bottom")
ax.grid()
plt.tight_layout()
plt.show()
